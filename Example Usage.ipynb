# %%
# Imports
from skinGAN import Skin_generator

# %%
# create new instance of skin generator using one of the supplied models
Generator = Skin_generator("models/Minecraft_skins_G9.pt")

# %%
# render skin, also get raw skin data
rendered, raw_skin = Generator.generate_skin()
rendered
# Out:
# test
# <PIL.Image.Image image mode=RGB size=680x360 at 0x218D925C040>

# %%
raw_skin
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x218D925C5E0>
